# %% [markdown]
# d-sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px">
# </div>

# %% [markdown]
# # Data Science Rapid Start: Preparing a Machine Learning Model

# %% [markdown]
# #### Step 1: Configure your Databricks notebook to perform your Moovio task.
#
# **Exercise**: Define the `username` variable below to be your preferred
# username.

# %%
# TODO
username = "hetraj"
dbutils.widgets.text("username", username)
spark.sql(f"CREATE DATABASE IF NOT EXISTS dbacademy_{username}")
spark.sql(f"USE dbacademy_{username}")
dbfs_path = f"/dbacademy/{username}/datasciencerapidstart/"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# spark.sql(f"DROP DATABASE IF EXISTS dbacademy_{username} CASCADE")

# %% [markdown]
# %md
# #### Step 2: Download the data
#
# This data is hosted on a Databricks server.

# %%
from urllib.request import urlretrieve

def retrieve_file(file_name: str) -> bool:
  URI = "https://files.training.databricks.com/static/data/health-tracker/" + file_name
  DRIVER_PATH = "file:/databricks/driver/" + file_name

  urlretrieve(URI, file_name)
  dbutils.fs.mv(DRIVER_PATH, dbfs_path + file_name)
  return True
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Retrieve Data
#
# **Exercise** Use the function `retrieve_file` to download the following files from
# cloud object storage.
#
# - "agg_data.csv"
# - "user_data.csv"

# %%
# TODO
retrieve_file("agg_data.csv")
retrieve_file("user_data.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: True</div>

# %% [markdown]
# ### Display the Downloaded Data
#
# The command below shows you where the data is saved.
#
# The `%fs` magic is a "file system" magic that provides a CLI-like interface
# to the Databricks File System in your Workspace.
#
# **Exercise**: Replace the value `<FILL_THIS_IN>` with the `username`
# you defined above.

# %%
# %fs ls /dbacademy/hetraj/datasciencerapidstart/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/dbacademy/hetraj/datasciencerapidstart/agg_data.csv</td><td>agg_data.csv</td><td>25001</td></tr><tr><td>dbfs:/dbacademy/hetraj/datasciencerapidstart/user_data.csv</td><td>user_data.csv</td><td>15371</td></tr></tbody></table></div>

# %% [markdown]
# #### Step 3: Load data into a Spark DataFrame
#
# DataFrames are the primary data structure for working with tabular data.

# %%
aggregateDataDF = (
  spark.read
  .option("header", True)
  .csv(dbfs_path + "agg_data.csv")
)
userDataDF = (
  spark.read
  .option("header", True)
  .csv(dbfs_path + "user_data.csv")
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Step 4: Display the data.
#
# First, we'll verify that both data files loaded correctly.
#
# In the Spark DataFrame "aggregateDataDF" we see average measurements per user over a series of months. In "userDataDF" we have self-identified lifestyle data with one of three attributes (weight trainer, sedentary, and cardio trainer).
#
# **Exercise:** Display the `aggregateDataDF` below.

# %%
# TODO
display(aggregateDataDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_id</th><th>avg(BMI)</th><th>avg(active_heartrate)</th><th>avg(resting_heartrate)</th><th>avg(VO2_max)</th></tr></thead><tbody><tr><td>de3cdb28-9569-11ea-b31d-0242ac110002</td><td>19.25617095674725</td><td>114.19669133161537</td><td>53.76342104178901</td><td>38.90740869552198</td></tr><tr><td>de3d7eb6-9569-11ea-b31d-0242ac110002</td><td>15.894914962508789</td><td>116.39613664650878</td><td>56.516242668721986</td><td>32.836879872385715</td></tr><tr><td>de3810ac-9569-11ea-b31d-0242ac110002</td><td
920323513187</td></tr><tr><td>de3e8edc-9569-11ea-b31d-0242ac110002</td><td>16.31548833216813</td><td>109.9781678018978</td><td>55.42728120464285</td><td>36.38618925965495</td></tr><tr><td>de3b8002-9569-11ea-b31d-0242ac110002</td><td>24.616169936078023</td><td>121.99988984813187</td><td>55.29879434671428</td><td>33.91915051146264</td></tr><tr><td>de39ce56-9569-11ea-b31d-0242ac110002</td><td>21.645645655684614</td><td>112.60801738613077</td><td>51.87889139154506</td><td>37.832118092320876</td></tr><tr><td>de418c5e-9569-11ea-b31d-0242ac110002</td><td>21.962644244224176</td><td>158.01180170615933</td><td>78.89908205084835</td><td>24.30949181798901</td></tr><tr><td>de3dc006-9569-11ea-b31d-0242ac110002</td><td>21.363569563851648</td><td>99.25590750208681</td><td>51.56128837088133</td><td>38.226818540059334</td></tr><tr><td>de3e4d00-9569-11ea-b31d-0242ac110002</td><td>21.981413395093405</td><td>102.71308694948131</td><td>50.67869823150549</td><td>41.82136829799561</td></tr><tr><td>de3923a2-9569-11ea-b31d-0242ac110002</td><td>24.030049766863737</td><td>114.92427881613406</td><td>56.4748455715011</td><td>32.86383582714725</td></tr><tr><td>de3ccafc-9569-11ea-b31d-0242ac110002</td><td>14.064488677807693</td><td>107.43905164659779</td><td>58.0826422130033</td><td>33.99939524735605</td></tr><tr><td>de3df7b0-9569-11ea-b31d-0242ac110002</td><td>25.489495936773626</td><td>96.63341837598571</td><td>49.24918403043516</td><td>45.59430655439121</td></tr><tr><td>de3c76ec-9569-11ea-b31d-0242ac110002</td><td>28.56897109978901</td><td>110.38216256019231</td><td>62.32003107610549</td><td>30.278765120046156</td></tr><tr><td>de3ce51e-9569-11ea-b31d-0242ac110002</td><td>20.0745016099967</td><td>100.11121844703298</td><td>54.22421102940331</td><td>35.83119076453186</td></tr><tr><td>de4131fa-9569-11ea-b31d-0242ac110002</td><td>22.631401215131863</td><td>124.53242151047361</td><td>76.63806300057033</td><td>24.234825353795603</td></tr><tr><td>de3da152-9569-11ea-b31d-0242ac110002</td><td>20.441640100158242</td><td> ...

# %% [markdown]
# ✏️ **Note**: Before moving forward, try experimenting with Databricks built-in
# visualizations. In the above cell, click the Bar Char icon in the bottom
# left-hand corner. Then, click on "Plot Options". Drag and drop the
# following variables from "All fields" to "Values": `avg(active_heartrate)`,
# `avg(VO2_max)`, `avg(resting_heartrate)`, `avg(BMI)`. Then, click Apply.

# %% [markdown]
# #### Step 6: Data manipulation
#
# Our ultimate goal in our Moovio task is to see if we can use the device-reported biometric data to predict the self-identified classification data. In order to do that, we need to join the biometric data with the user data. From there, we will identify the data to be used in our classification model.
#
# **Exercise**: Create the `joinedDF` by joining `aggregateDataDF` and `userDataDF`
# on the `_id` column.
#
# 🏋🏽‍♀️ You can use this syntax to perform your join:
#
# ```
# df1.join(df2, "join_column")
# ```

# %%
# TODO
joinedDF = aggregateDataDF.join(userDataDF, "_id")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ####
1882047178901</td><td>87.79865278007031</td><td>18.57920323513187</td><td>210</td><td>Kristen</td><td>Wells</td><td>sedentary</td></tr><tr><td>de3e8edc-9569-11ea-b31d-0242ac110002</td><td>16.31548833216813</td><td>109.9781678018978</td><td>55.42728120464285</td><td>36.38618925965495</td><td>127</td><td>Bethany</td><td>Thomas</td><td>cardio trainer</td></tr><tr><td>de3b8002-9569-11ea-b31d-0242ac110002</td><td>24.616169936078023</td><td>121.99988984813187</td><td>55.29879434671428</td><td>33.91915051146264</td><td>50</td><td>Helen</td><td>Schneider</td><td>weight trainer</td></tr><tr><td>de39ce56-9569-11ea-b31d-0242ac110002</td><td>21.645645655684614</td><td>112.60801738613077</td><td>51.87889139154506</td><td>37.832118092320876</td><td>27</td><td>Connie</td><td>Woods</td><td>weight trainer</td></tr><tr><td>de418c5e-9569-11ea-b31d-0242ac110002</td><td>21.962644244224176</td><td>158.01180170615933</td><td>78.89908205084835</td><td>24.30949181798901</td><td>223</td><td>Brenda</td><td>White</td><td>sedentary</td></tr><tr><td>de3dc006-9569-11ea-b31d-0242ac110002</td><td>21.363569563851648</td><td>99.25590750208681</td><td>51.56128837088133</td><td>38.226818540059334</td><td>105</td><td>Melanie</td><td>Richardson</td><td>cardio trainer</td></tr><tr><td>de3e4d00-9569-11ea-b31d-0242ac110002</td><td>21.981413395093405</td><td>102.71308694948131</td><td>50.678698231 ...

# %% [markdown]
# Note: This time, visualize this data as a bar chart by configuring it
# is follows - Keys: `lifestyle`; Values: `avg(active_heartrate)`,
# `avg(VO2_max)`, `avg(resting_heartrate)`, `avg(BMI)`

# %% [markdown]
# #### Step 8: Convert joined data to a Pandas DataFrame.
#
# With the size of this data, it will be easier to train our model using
# scikit-learn. This is why we convert it to a Pandas DataFrame.
# Then, we display the data to verify that it was loaded correctly.
#
# **Exercise:** Convert `joinedDF` to a Pandas DataFrame.
#
# 🐼 You can do this with the `.toPandas()` DataFrame method.

# %%
# TODO
joined_pd_df = joinedDF.toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ##### Display the `.head()` of the Pandas DataFrame

# %%
joined_pd_df.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>_id</th>
#       <th>avg(BMI)</th>
#       <th>avg(active_heartrate)</th>
#       <th>avg(resting_heartrate)</th>
#       <th>avg(VO2_max)</th>
#       <th>_c0</th>
#       <th>first_name</th>
#       <th>last_name</th>
#       <th>lifestyle</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>de3cdb28-9569-11ea-b31d-0242ac110002</td>
#       <td>19.25617095674725</td>
#       <td>114.19669133161537</td>
#       <td>53.76342104178901</td>
#       <td>38.90740869552198</td>
#       <td>79</td>
#       <td>Elizabeth</td>
#       <td>Hunter</td>
#       <td>cardio trainer</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>de3d7eb6-9569-11ea-b31d-0242ac110002</td>
#       <td>15.894914962508789</td>
#       <td>116.39613664650878</td>
#       <td>56.516242668721986</td>
#       <td>32.836879872385715</td>
#       <td>99</td>
#       <td>Annette</td>
#       <td>Rodriguez</td>
#       <td>cardio trainer</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>de3810ac-9569-11ea-b31d-0242ac110002</td>
#       <td>25.72690922765604</td>
#       <td>115.05437032988571</td>
#       <td>55.213060720312086</td>
#       <td>31.923265506356046</td>
#       <td>3</td>
#       <td>Tracy</td>
#       <td>Townsend</td>
#       <td>weight trainer</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>de3a3d46-9569-11ea-b31d-0242ac110002</td>
#       <td>19.420948098308788</td>
#       <td>108.1710862204066</td>
#       <td>54.14200223673406</td>
#       <td>37.778142411659346</td>
#       <td>33</td>
#       <td>Lisa</td>
#       <td>Perry</td>
#       <td>weight trainer</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>de404c54-9569-11ea-b31d-0242ac110002</td>
#       <td>31.956450079953846</td>
#       <td>123.25956405440658</td>
#       <td>62.8442030077088</td>
#       <td>32.12877429878352</td>
#       <td>181</td>
#       <td>Melinda</td>
#       <td>Rhodes</td>
#       <td>sedentary</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### Step 9: Preparing features and target
#
# To prepare our model, we need features and target. Here, we prepare those
# from the Pandas DataFrame.
#
# 🤠 **Note:** the remaining cells in this notebook are advanced and are
# included in this introductory notebook for demonstration purposes.

# %% [markdown]
# In this cell, we select just the numerical features and then numerically
# encode the target vector.

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
features = joined_pd_df[["avg(BMI)", "avg(active_heartrate)", "avg(resting_heartrate)", "avg(VO2_max)"]]
target = joined_pd_df.lifestyle
target_numerical = le.fit_transform(target)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Step 10: Train a machine learning model
#
# In the next few steps, we use MLflow to prepare a machine learning model.

# %% [markdown]
# First, we split the data into training and testing datasets.

# %%
from sklearn.model_selection import train_test_split

(X_train, X_test, y_train, y_test) = train_test_split(features, target_numerical)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Next, we import the machine learning models that we will use.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Finally, we test each of these models on our data using MLflow.

# %%
import mlflow

with mlflow.start_run() as run:
  model = LogisticRegression(max_iter=1e5)
  model.fit(X_train, y_train)

  train_accuracy = model.score(X_train, y_train)
  test_accuracy = model.score(X_test, y_test)
  mlflow.log_param("model", model.__class__)
  mlflow.log_metric("train_accuracy", train_accuracy)
  mlflow.log_metric("test_accuracy", test_accuracy)

with mlflow.start_run() as run:
  model = DecisionTreeClassifier()
  model.fit(X_train, y_train)

  train_accuracy = model.score(X_train, y_train)
  test_accuracy = model.score(X_test, y_test)
  mlflow.log_param("model", model.__class__)
  mlflow.log_metric("train_accuracy", train_accuracy)
  mlflow.log_metric("test_accuracy", test_accuracy)

with mlflow.start_run() as run:
  model = KNeighborsClassifier()
  model.fit(X_train, y_train)

  train_accuracy = model.score(X_train, y_train)
  test_accuracy = model.score(X_test, y_test)
  mlflow.log_param("model", model.__class__)
  mlflow.log_metric("train_accuracy", train_accuracy)
  mlflow.log_metric("test_accuracy", test_accuracy)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Step 11: View model training results
#
# Step 11: View model training results
# In the upper right hand corner of this notebook. click "Experiment".
# A list of all of your runs will appear. At the bottom of that list,
# click on Experiment UI in order to get more information about each run.

# %% [markdown]
# #### Step 12: Make a decision
#
# Do you have enough information to make a decision about what type of
# model to use? Why or why not? How would you move forward?

# %% [markdown]
# -sandbox
# &copy; 2020 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
